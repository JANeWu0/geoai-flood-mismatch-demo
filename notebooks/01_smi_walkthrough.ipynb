# %% [markdown]
# # SMI Walkthrough
#
# This notebook demonstrates the Spatial Mismatch Index using the sample dataset.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT / 'src'))
from flood_mismatch.data_loader import load_sample_municipalities
from flood_mismatch.smi import add_mismatch_columns
df = load_sample_municipalities(ROOT / 'data' / 'sample_municipalities.csv')
result, smi = add_mismatch_columns(df)
smi

# %%
result.sort_values('mismatch_residual')[['name','impact_share','response_share','mismatch_residual','mismatch_label']]
